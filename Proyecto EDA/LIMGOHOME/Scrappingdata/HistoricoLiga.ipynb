# %%
import lxml
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
historico = pd.read_html("https://fbref.com/es/equipos/dcc91a7b/historia/Estadisticas-e-historial-de-Valencia")

# %%
liga_hist = pd.DataFrame(historico[0])

# %%
liga_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Temporada                   36 non-null     object
#  1   Equipo                      36 non-null     object
#  2   País                        36 non-null     object
#  3   Comp                        36 non-null     object
#  4   RangoLg                     36 non-null     object
#  5   PJ                          36 non-null     int64
#  6   PG                          36 non-null     int64
#  7   PE                          36 non-null     int64
#  8   PP                          36 non-null     int64
#  9   GF                          36 non-null     int64
#  10  GC                          36 non-null     int64
#  11  DG                          36 non-null     int64
#  12  Pts                         36 non-null     int64
# ...

# %%
liga_hist = liga_hist.drop(columns=["Máximo Goleador del Equipo", "Portero", "Notas"])

# %%
liga_hist.RangoLg = liga_hist.RangoLg.str.extract(r'(\d+)').astype(int)

# %%
liga_hist["Posicion"] = liga_hist.RangoLg

# %%
liga_hist = liga_hist.drop(columns=["RangoLg"])

# %%
liga_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Temporada   36 non-null     object
#  1   Equipo      36 non-null     object
#  2   País        36 non-null     object
#  3   Comp        36 non-null     object
#  4   PJ          36 non-null     int64
#  5   PG          36 non-null     int64
#  6   PE          36 non-null     int64
#  7   PP          36 non-null     int64
#  8   GF          36 non-null     int64
#  9   GC          36 non-null     int64
#  10  DG          36 non-null     int64
#  11  Pts         36 non-null     int64
#  12  Asistencia  25 non-null     float64
#  13  Posicion    36 non-null     int32
# dtypes: float64(1), int32(1), int64(8), object(4)
# memory usage: 3.9+ KB

# %%
liga_hist = liga_hist.dropna()

# %%
liga_hist.head(20)
# Out:
#     Temporada    Equipo    País        Comp  PJ  PG  PE  PP  GF  GC  DG  Pts  \
# 0   2023-2024  Valencia  es ESP  1. La Liga  31  13   8  10  34  32   2   47
# 1   2022-2023  Valencia  es ESP  1. La Liga  38  11   9  18  42  45  -3   42
# 2   2021-2022  Valencia  es ESP  1. La Liga  38  11  15  12  48  53  -5   48
# 3   2020-2021  Valencia  es ESP  1. La Liga  38  10  13  15  50  53  -3   43
# 4   2019-2020  Valencia  es ESP  1. La Liga  38  14  11  13  46  53  -7   53
# 5   2018-2019  Valencia  es ESP  1. La Liga  38  15  16   7  51  35  16   61
# 6   2017-2018  Valencia  es ESP  1. La Liga  38  22   7   9  65  38  27   73
# 7   2016-2017  Valencia  es ESP  1. La Liga  38  13   7  18  56  65  -9   46
# 8   2015-2016  Valencia  es ESP  1. La Liga  38  11  11  16  46  48  -2   44
# 9   2014-2015  Valencia  es ESP  1. La Liga  38  22  11   5  70  32  38   77
# 10  2013-2014  Valencia  es ESP  1. La Liga  38  13  10  15  51  53  -2   49
# ...

# %%
ruta="D:\DATASCIENCE\Repositorios\ONLINE_DS_THEBRIDGE_RAULSOLER\Proyecto EDA\LIMGOHOME\DatasLimpios\historico_y_asistencia.csv"

liga_hist.to_csv(ruta, index="False")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\raul_\AppData\Local\Temp\ipykernel_12928\3264439754.py:1: SyntaxWarning: invalid escape sequence '\D'
#   ruta="D:\DATASCIENCE\Repositorios\ONLINE_DS_THEBRIDGE_RAULSOLER\Proyecto EDA\LIMGOHOME\DatasLimpios\historico_y_asistencia.csv"
