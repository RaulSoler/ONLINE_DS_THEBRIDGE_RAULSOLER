# %%
import lxml
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
from fake_useragent import UserAgent                
ua = UserAgent()
headers = {'User-Agent': ua.random}

# %%
url = "https://www.transfermarkt.es/valencia-cf/kader/verein/1049/plus/0/galerie/0?saison_id=2013"

# %%
plantilla14 = requests.get(url, headers=headers)

# %%
plantilla14 = BeautifulSoup(plantilla14.text, "html.parser")

# %%
temp14={"Nombre":[],
        "Posicion":[],
        "Edad":[],
        "Nacionalidad":[],
        "Valor":[]
        }

# %% [markdown]
# SACAR NOMBRE JUGADOR

# %%
nombres = plantilla14.find_all('img', class_='bilderrahmen-fixed lazy lazy')
for nombre in nombres:
    #jugador24 = nombre["title"]
    temp14["Nombre"].append(nombre["title"])

# %% [markdown]
# SACAR EDAD JUGADOR
#
# Veo que desde la posicion 1 y cada 4 saco el TD donde esta la edad ya que ese campo no tiene ningún atributo o clase que pueda diferenciar del resto.
# Saco la longitud total de el td para saber su longitud y recorrer cada campo de la edad.

# %%
edad = plantilla14.find_all("td",class_ = "zentriert")

longitud=(len(edad)-4) #Saco el total y en el range le pongo 97 porque es el último valor de la cadena que queremos sacar.

valores_edad = [edad[i].text.strip() for i in range(1, longitud, 4)]
temp14["Edad"]=valores_edad

# %% [markdown]
# SACAR LA POSICION
# Como en el anterior no tenemos una etiqueta ni nada que nos indique el campo de la posicion tenemos que sacarlo
# a traves de la posicion de la etiqueta.

# %%
posiciones = plantilla14.find_all("table",class_ = "inline-table")

longitud_pos = (len(posiciones))
for i in range(longitud_pos):
    #print(posiciones[i].find_all("td")[2].text.strip())
    temp14["Posicion"].append(posiciones[i].find_all("td")[2].text.strip())

# %% [markdown]
# SACAR NACIONALIDAD
#
# saco el td con la clase, veo que los que tienen doble nacionalidad ocupan td diferentes por eso le decimos que coja todos los "img" y la primera posicion de cada td.

# %%
nacionalidades = plantilla14.find_all("td", class_='zentriert')
for nacion in nacionalidades:
    img = nacion.find_all("img", class_="flaggenrahmen")
    if img:
        #print(img[0].get("title"))
        temp14["Nacionalidad"].append(img[0].get("title"))

# %%
temporada14 =  pd.DataFrame(temp14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 temporada14 =  pd.DataFrame(temp14)
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
temporada14
# Out:
#                Nombre              Posicion  Edad            Nacionalidad  \
# 0         Diego Alves               Portero    29                  Brasil
# 1      Vicente Guaita               Portero    27                  España
# 2      Jaume Doménech               Portero    23                  España
# 3       Héctor Pizana               Portero    19                  España
# 4      Antonio Sivera               Portero    17                  España
# 5    Nicolás Otamendi       Defensa central    26               Argentina
# 6           Adil Rami       Defensa central    28                 Francia
# 7        Aly Cissokho       Defensa central    26                 Francia
# 8         Víctor Ruiz       Defensa central    25                  España
# 9       Ricardo Costa       Defensa central    33                Portugal
# 10  Philippe Senderos       Defensa central    29                   Suiza
# 11         Rúben Vezo       Defensa central    20                Portugal
# 12       Sergio Ayala       Defensa central    21                  España
# 13     Jérémy Mathieu     Lateral izquierdo    30                 Francia
# 14        Juan Bernat     Lateral izquierdo    21                  España
# 15          José Gayà     Lateral izquierdo    19                  España
# 16         Salva Ruiz     Lateral izquierdo    19                  España
# 17       João Pereira       Lateral derecho    30                Portugal
# 18   Antonio Barragán       Lateral derecho    27                  España
# 19   Sofiane Feghouli                Pivote    24                 Argelia
# 20        Oriol Romeu                Pivote    22                  España
# 21         Javi Fuego                Pivote    30                  España
# 22          Lion Kaak                Pivote    23            Países Bajos
# 23        Éver Banega           Mediocentro    26               Argentina
# 24        Dani Parejo           Mediocentro    25                  España
# 25    Andrés Guardado           Mediocentro    27                  México
# 26     Míchel Herrero           Mediocentro    25                  España
# 27       Seydou Keita           Mediocentro    34                    Malí
# 28        Manu Molina           Mediocentro    22                  España
# 29       Mario Arqués           Mediocentro    22                  España
# 30     Sergio Canales  Mediocentro ofensivo    23                  España
# 31     Jonathan Viera  Mediocentro ofensivo    24                  España
# 32       Pablo Piatti     Extremo izquierdo    25               Argentina
# 33       Dorlan Pabón       Extremo derecho    26                Colombia
# 34      Fede Cartabia       Extremo derecho    21  Emiratos Árabes Unidos
# 35              Portu       Extremo derecho    22                  España
# 36       Rober Ibáñez       Extremo derecho    21                  España
# 37              Jonas            Mediapunta    30                  Brasil
# 38     Eduardo Vargas      Delantero centro    24                   Chile
# 39       Paco Alcácer      Delantero centro    20                  España
# 40     Hélder Postiga      Delantero centro    31                Portugal
# 41    Vinícius Araújo      Delantero centro    21                  Brasil
#
#     Valor millones
# 0              6.0
# 1              5.0
# 2              0.2
# 3              0.2
# 4              0.2
# 5             12.0
# 6              8.0
# 7              6.0
# 8              5.0
# 9              3.0
# 10             2.5
# 11             1.6
# 12             0.2
# 13             9.0
# 14             4.0
# 15             1.0
# 16             0.2
# 17             6.0
# 18             2.0
# 19            12.0
# 20             7.0
# 21             4.0
# 22             0.2
# 23            12.0
# 24            10.0
# 25             6.0
# 26             3.5
# 27             1.5
# 28             0.2
# 29             0.2
# 30             5.0
# 31             4.0
# 32             4.0
# 33             5.0
# 34             3.0
# 35             0.2
# 36             0.2
# 37            12.0
# 38             6.0
# 39             6.0
# 40             3.5
# 41             3.0

# %%
temporada14.head(10)
# Out:
#              Nombre         Posicion  Edad Nacionalidad  Valor millones
# 0       Diego Alves          Portero    29       Brasil             6.0
# 1    Vicente Guaita          Portero    27       España             5.0
# 2    Jaume Doménech          Portero    23       España             0.2
# 3     Héctor Pizana          Portero    19       España             0.2
# 4    Antonio Sivera          Portero    17       España             0.2
# 5  Nicolás Otamendi  Defensa central    26    Argentina            12.0
# 6         Adil Rami  Defensa central    28      Francia             8.0
# 7      Aly Cissokho  Defensa central    26      Francia             6.0
# 8       Víctor Ruiz  Defensa central    25       España             5.0
# 9     Ricardo Costa  Defensa central    33     Portugal             3.0

# %%
temporada14.Edad = temporada14.Edad.astype(int)

# %%
temporada14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Nombre          42 non-null     object
#  1   Posicion        42 non-null     object
#  2   Edad            42 non-null     int32
#  3   Nacionalidad    42 non-null     object
#  4   Valor millones  42 non-null     float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 1.6+ KB

# %%
temporada14.Valor = temporada14.Valor.str.replace("[^\d,.]", "", regex=True).str.replace(",", ".").str.extract(r'(\d+.\d+|\d+)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\raul_\AppData\Local\Temp\ipykernel_22924\1117496087.py:1: SyntaxWarning: invalid escape sequence '\d'
#   temporada14.Valor = temporada14.Valor.str.replace("[^\d,.]", "", regex=True).str.replace(",", ".").str.extract(r'(\d+.\d+|\d+)').astype(float)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22924\1117496087.py in ?()
# ----> 1 temporada14.Valor = temporada14.Valor.str.replace("[^\d,.]", "", regex=True).str.replace(",", ".").str.extract(r'(\d+.\d+|\d+)').astype(float)
#
# c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Valor'

# %% [markdown]
# Pasamos los valores a millones, sabemos que los valores altos que habian no corresponden al valor en millones ya que sabemos que
# la plantilla del valencia no tiene jugadores tan valiosos.

# %%
temporada14.loc[temporada14.Valor > 100,"Valor"] = temporada14.loc[temporada14.Valor > 100,"Valor"]/1000
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22924\1328606121.py in ?()
# ----> 1 temporada14.loc[temporada14.Valor > 100,"Valor"] = temporada14.loc[temporada14.Valor > 100,"Valor"]/1000
#
# c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Valor'

# %%
temporada14["Valor millones"] = temporada14.Valor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22924\2351609834.py in ?()
# ----> 1 temporada14["Valor millones"] = temporada14.Valor
#
# c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Valor'

# %%
temporada14 = temporada14.drop(columns=["Valor"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 temporada14 = temporada14.drop(columns=["Valor"])
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4785, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4783 for axis, labels in axes.items():
#    4784     if labels is not None:
# -> 4785         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4787 if inplace:
#    4788     self._update_inplace(obj)
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4827, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4825         new_axis = axis.drop(labels, level=level, errors=errors)
#    4826     else:
# -> 4827         new_axis = axis.drop(labels, errors=errors)
#    4828     indexer = axis.get_indexer(new_axis)
#    4830 # Case for non-unique axis
#    4831 else:
#
# File c:\Users\raul_\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Valor'] not found in axis"

# %%
temporada14
# Out:
#                Nombre              Posicion  Edad            Nacionalidad  \
# 0         Diego Alves               Portero    29                  Brasil
# 1      Vicente Guaita               Portero    27                  España
# 2      Jaume Doménech               Portero    23                  España
# 3       Héctor Pizana               Portero    19                  España
# 4      Antonio Sivera               Portero    17                  España
# 5    Nicolás Otamendi       Defensa central    26               Argentina
# 6           Adil Rami       Defensa central    28                 Francia
# 7        Aly Cissokho       Defensa central    26                 Francia
# 8         Víctor Ruiz       Defensa central    25                  España
# 9       Ricardo Costa       Defensa central    33                Portugal
# 10  Philippe Senderos       Defensa central    29                   Suiza
# 11         Rúben Vezo       Defensa central    20                Portugal
# 12       Sergio Ayala       Defensa central    21                  España
# 13     Jérémy Mathieu     Lateral izquierdo    30                 Francia
# 14        Juan Bernat     Lateral izquierdo    21                  España
# 15          José Gayà     Lateral izquierdo    19                  España
# 16         Salva Ruiz     Lateral izquierdo    19                  España
# 17       João Pereira       Lateral derecho    30                Portugal
# 18   Antonio Barragán       Lateral derecho    27                  España
# 19   Sofiane Feghouli                Pivote    24                 Argelia
# 20        Oriol Romeu                Pivote    22                  España
# 21         Javi Fuego                Pivote    30                  España
# 22          Lion Kaak                Pivote    23            Países Bajos
# 23        Éver Banega           Mediocentro    26               Argentina
# 24        Dani Parejo           Mediocentro    25                  España
# 25    Andrés Guardado           Mediocentro    27                  México
# 26     Míchel Herrero           Mediocentro    25                  España
# 27       Seydou Keita           Mediocentro    34                    Malí
# 28        Manu Molina           Mediocentro    22                  España
# 29       Mario Arqués           Mediocentro    22                  España
# 30     Sergio Canales  Mediocentro ofensivo    23                  España
# 31     Jonathan Viera  Mediocentro ofensivo    24                  España
# 32       Pablo Piatti     Extremo izquierdo    25               Argentina
# 33       Dorlan Pabón       Extremo derecho    26                Colombia
# 34      Fede Cartabia       Extremo derecho    21  Emiratos Árabes Unidos
# 35              Portu       Extremo derecho    22                  España
# 36       Rober Ibáñez       Extremo derecho    21                  España
# 37              Jonas            Mediapunta    30                  Brasil
# 38     Eduardo Vargas      Delantero centro    24                   Chile
# 39       Paco Alcácer      Delantero centro    20                  España
# 40     Hélder Postiga      Delantero centro    31                Portugal
# 41    Vinícius Araújo      Delantero centro    21                  Brasil
#
#     Valor millones
# 0              6.0
# 1              5.0
# 2              0.2
# 3              0.2
# 4              0.2
# 5             12.0
# 6              8.0
# 7              6.0
# 8              5.0
# 9              3.0
# 10             2.5
# 11             1.6
# 12             0.2
# 13             9.0
# 14             4.0
# 15             1.0
# 16             0.2
# 17             6.0
# 18             2.0
# 19            12.0
# 20             7.0
# 21             4.0
# 22             0.2
# 23            12.0
# 24            10.0
# 25             6.0
# 26             3.5
# 27             1.5
# 28             0.2
# 29             0.2
# 30             5.0
# 31             4.0
# 32             4.0
# 33             5.0
# 34             3.0
# 35             0.2
# 36             0.2
# 37            12.0
# 38             6.0
# 39             6.0
# 40             3.5
# 41             3.0

# %%
#temporada22["Valor millones"].fillna(temporada22["Valor millones"].min, inplace=True)
min_valor = temporada14["Valor millones"].min()
temporada14["Valor millones"].fillna(min_valor, inplace=True)
# Out:
# C:\Users\raul_\AppData\Local\Temp\ipykernel_22924\231190544.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   temporada14["Valor millones"].fillna(min_valor, inplace=True)

# %%
ruta="D:\DATASCIENCE\Repositorios\ONLINE_DS_THEBRIDGE_RAULSOLER\Proyecto EDA\LIMGOHOME\DatasLimpios\Temporada14_13.csv"

temporada14.to_csv(ruta, index="False")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\raul_\AppData\Local\Temp\ipykernel_22924\1458505115.py:1: SyntaxWarning: invalid escape sequence '\D'
#   ruta="D:\DATASCIENCE\Repositorios\ONLINE_DS_THEBRIDGE_RAULSOLER\Proyecto EDA\LIMGOHOME\DatasLimpios\Temporada14_13.csv"
