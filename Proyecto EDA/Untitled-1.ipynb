# %%
import pandas as pd

# %%
df_ataque = pd.read_csv("./championsdata/attacking.csv")

# %%
df_ataque.head(20)
# Out:
#     serial       player_name         club    position  assists  corner_taken  \
# 0        1   Bruno Fernandes  Man. United  Midfielder        7            10
# 1        2   Vinícius Júnior  Real Madrid     Forward        6             3
# 2        2              Sané       Bayern  Midfielder        6             3
# 3        4            Antony         Ajax     Forward        5             3
# 4        5  Alexander-Arnold    Liverpool    Defender        4            36
# 5        5         De Bruyne    Man. City  Midfielder        4            18
# 6        5            Modrić  Real Madrid  Midfielder        4            10
# 7        5        João Mário      Benfica  Midfielder        4             8
# 8        5            Mbappé        Paris     Forward        4             4
# 9        5     Gerard Moreno   Villarreal     Forward        4             0
# 10       5            Capoue   Villarreal  Midfielder        4             0
# ...

# %%
df_int = pd.read_csv("./championsdata/attempts.csv")

# %%
df_int.head(10)
# Out:
#    serial      player_name         club    position  total_attempts  \
# 0       1          Benzema  Real Madrid     Forward              45
# 1       2            Salah    Liverpool     Forward              42
# 2       3           Mahrez    Man. City  Midfielder              37
# 3       4             Sané       Bayern  Midfielder              33
# 4       5      Lewandowski       Bayern     Forward              31
# 5       6        Luis Díaz        Porto     Forward              29
# 6       7         Martínez        Inter     Forward              28
# 7       8           Mbappé        Paris     Forward              27
# 8       8  Vinícius Júnior  Real Madrid     Forward              27
# 9      10          Havertz      Chelsea  Midfielder              26
#
#    on_target  off_target  blocked  match_played
# 0         23          13        9            12
# 1         22          11        9            13
# 2         18           8       11            12
# ...

# %%
df_def = pd.read_csv("./championsdata/defending.csv")

# %%
df_def.head(10)
# Out:
#    serial   player_name         club    position  balls_recoverd  tackles  \
# 0       1      Casemiro  Real Madrid  Midfielder              76       31
# 1       1  Éder Militão  Real Madrid    Defender              76       19
# 2       1      Reinildo     Atlético    Defender              76       13
# 3       4       Fabinho    Liverpool  Midfielder              74       23
# 4       5        Albiol   Villarreal    Defender              73        9
# 5       6  Thiago Silva      Chelsea    Defender              65        9
# 6       7      Otamendi      Benfica    Defender              63       28
# 7       8        Capoue   Villarreal  Midfielder              62       11
# 8       8      Van Dijk    Liverpool    Defender              62        3
# 9      10  João Cancelo    Man. City    Defender              56        9
#
#    t_won  t_lost  clearance_attempted  match_played
# 0     13      18                   19            11
# ...

# %%
df_disci = pd.read_csv("./championsdata/disciplinary.csv")

# %%
df_disci.loc[df_disci.fouls_committed].groupby("club").value_counts()
# Out:
# club         serial  player_name   position    fouls_committed  fouls_suffered  red  yellow  minutes_played  match_played
# Ajax         6       Haller        Forward     17               11              1    0       668             8               23
#                      Álvarez       Midfielder  17               6               4    0       558             7               16
#                      Gravenberch   Midfielder  17               11              1    0       703             8               13
# Atlético     16      Reinildo      Defender    15               15              2    0       816             10               4
# Barcelona    12      Gavi          Midfielder  16               7               2    0       398             6                6
# Benfica      6       Otamendi      Defender    17               11              2    0       810             9               39
# ...

# %%
df_disci.head(3)
# Out:
#    serial    player_name         club    position  fouls_committed  \
# 0       1  João Palhinha  Sporting CP  Midfielder               23
# 1       2         Capoue   Villarreal  Midfielder               19
# 2       2          Rodri    Man. City  Midfielder               19
#
#    fouls_suffered  red  yellow  minutes_played  match_played
# 0              17    2       0             534             6
# 1              17    3       1            1046            12
# 2               4    2       0             842            10

# %%
df_dis = pd.read_csv("./championsdata/distributon.csv")

# %%
df_dis.head(30)
# Out:
#     serial      player_name              club    position  pass_accuracy  \
# 0        1          Erokhin             Zenit  Midfielder           98.0
# 1        2      Eric García         Barcelona    Defender           97.5
# 2        3          Ulreich            Bayern  Goalkeeper           97.0
# 3        4           Rugani          Juventus    Defender           96.8
# 4        5        J. Timber              Ajax  Midfielder           95.8
# 5        6       Egan-Riley         Man. City    Defender           95.0
# 6        6     Mario Gaspar        Villarreal    Defender           95.0
# 7        8           Marlon  Shakhtar Donetsk    Defender           94.8
# 8        9             Süle            Bayern    Defender           94.7
# 9        9          Laporte         Man. City    Defender           94.7
# 10      11           Maycon  Shakhtar Donetsk  Midfielder           94.5
# 11      11          Nianzou            Bayern  Midfielder           94.5
# ...

# %%
df_porte= pd.read_csv("./championsdata/goalkeeping.csv")

# %%
df_porte.head(10)
# Out:
#    serial       player_name         club    position  saved  conceded  \
# 0       1          Courtois  Real Madrid  Goalkeeper     61        14
# 1       2             Rulli   Villarreal  Goalkeeper     41        16
# 2       3       Vlachodimos      Benfica  Goalkeeper     38        17
# 3       4      Athanasiadis      Sheriff  Goalkeeper     29         8
# 4       5          Mignolet  Club Brugge  Goalkeeper     28        20
# 5       6             Oblak     Atlético  Goalkeeper     26        10
# 6       7             Musso     Atalanta  Goalkeeper     21        13
# 7       8  Ersin Destanoğlu     Beşiktaş  Goalkeeper     20        17
# 8       9            De Gea  Man. United  Goalkeeper     19         9
# 9       9            Dahlin        Malmö  Goalkeeper     19         8
#
#    saved_penalties  cleansheets  punches made  match_played
# 0                1            5             4            13
# 1                0            3            12            12
# ...

# %%
df_goles = pd.read_csv("./championsdata/goals.csv")

# %%
df_goles.head(10)
# Out:
#    serial  player_name         club    position  goals  right_foot  left_foot  \
# 0       1      Benzema  Real Madrid     Forward     15          11          1
# 1       2  Lewandowski       Bayern     Forward     13           8          3
# 2       3       Haller         Ajax     Forward     11           3          4
# 3       4        Salah    Liverpool     Forward      8           0          8
# 4       5       Nkunku      Leipzig  Midfielder      7           3          1
# 5       5       Mahrez    Man. City  Midfielder      7           1          4
# 6       7       Mbappé        Paris     Forward      6           6          0
# 7       7        Núñez      Benfica     Forward      6           5          0
# 8       7      Ronaldo  Man. United     Forward      6           5          0
# 9       7      Danjuma   Villarreal  Midfielder      6           3          3
#
#    headers  others  inside_area  outside_areas  penalties  match_played
# ...

# %%
df_goles.groupby("club")["goals"].sum().sort_values(ascending=False)
# Out:
# club
# Bayern              30
# Liverpool           30
# Real Madrid         28
# Man. City           28
# Ajax                21
# Chelsea             21
# Villarreal          20
# Paris               15
# Leipzig             15
# Sporting CP         14
# Benfica             13
# Atalanta            12
# Man. United         12
# Juventus            11
# Salzburg            10
# Dortmund            10
# Zenit                9
# Inter                9
# Atlético             9
# LOSC                 8
# Sheriff              7
# Young Boys           7
# Milan                5
# Club Brugge          5
# Sevilla              5
# Wolfsburg            5
# Beşiktaş             3
# Porto                2
# Shakhtar Donetsk     2
# Barcelona            2
# Dynamo Kyiv          1
# Malmö                1
# Name: goals, dtype: int64

# %%
df_stats = pd.read_csv("./championsdata/key_stats.csv")

# %%
df_stats.head(100)
# Out:
#         player_name         club    position  minutes_played  match_played  \
# 0          Courtois  Real Madrid  Goalkeeper            1230            13
# 1   Vinícius Júnior  Real Madrid     Forward            1199            13
# 2           Benzema  Real Madrid     Forward            1106            12
# 3            Modrić  Real Madrid  Midfielder            1077            13
# 4      Éder Militão  Real Madrid    Defender            1076            12
# ..              ...          ...         ...             ...           ...
# 95          Kimmich       Bayern  Midfielder             702             8
# 96  Marcos Llorente     Atlético  Midfielder             700             9
# 97      Azpilicueta      Chelsea    Defender             679             9
# 98            David         LOSC     Forward             679             8
# 99           Mbappé        Paris     Forward             673             8
#
#     goals  assists distance_covered
# ...
